# %% [markdown]
# <a href="https://colab.research.google.com/github/9CORE2/sort-google-scholar/blob/dev/examples/run_sortgs_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Try `sortgs.py` on Google Colab
# This is a jupyter envirnment where you can try the code of the repository without installing anything. The only limitation is the robot checking problem which would require selenium and manual solution of the captchas, but for trying a few keywords, it should work!
#
# > **INSTRUCTIONS:** If this is the first time you are using a jupyter environment, you simply have to run the code blocks using the keyword `SHIFT` + `ENTER`. Make sure to update the keyword parameters when required.
#
# SortGS has been recently included to PyPI, so the instructions here got simpler. First, let's install the package:

# %%
# !pip install sortgs
# Out:
# Collecting sortgs
#   Downloading sortgs-1.0.7-py3-none-any.whl.metadata (9.1 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from sortgs) (4.13.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from sortgs) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from sortgs) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sortgs) (2.32.4)
# Collecting selenium (from sortgs)
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->sortgs) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->sortgs) (4.15.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->sortgs) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->sortgs) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->sortgs) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sortgs) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sortgs) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->sortgs) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sortgs) (2025.10.5)
# Collecting trio<1.0,>=0.31.0 (from selenium->sortgs)
#   Downloading trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium->sortgs)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from selenium->sortgs) (1.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->sortgs) (1.17.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium->sortgs) (25.4.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium->sortgs) (2.4.0)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium->sortgs)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium->sortgs) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium->sortgs)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.5.0->selenium->sortgs) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium->sortgs) (0.16.0)
# Downloading sortgs-1.0.7-py3-none-any.whl (9.6 kB)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 66.9 MB/s eta 0:00:00
# Downloading trio-0.32.0-py3-none-any.whl (512 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.0/512.0 kB 37.0 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, outcome, trio, trio-websocket, selenium, sortgs
# Successfully installed outcome-1.3.0.post0 selenium-4.38.0 sortgs-1.0.7 trio-0.32.0 trio-websocket-0.12.2 wsproto-1.2.0

# %% [markdown]
# Next, let's run it in the command line. Make sure to change "deep learning" to the keyword that you would like to have it ranked.

# %%
# Change 'deep learning' with the keyword that you would like to check
# !sortgs '"AI Literacy" AND "scale"' --sortby "cit/year"
# !sortgs "deep learning" --nresults 50
# Out:
# Running with the following parameters:
# Keyword: deep learning, Number of results: 50, Save database: True, Path: /content, Sort by: Citations, Permitted Languages: All, Plot results: False, Start year: None, End year: 2025, Debug: False
# Loading next 10 results
# Loading next 20 results
# Loading next 30 results
# Loading next 40 results
# Loading next 50 results
# Empty DataFrame
# Columns: [Author, Title, Citations, Year, Publisher, Venue, Source, cit/year]
# Index: []
# Results saved to /content/deep_learning.csv

# %% [markdown]
# > _**NOTE:** It is normal to get some warnings, for example year not found or author not found. However, if you get the robot checking warning, then it might not work anymore in the IP that you have on Google Colab. You can try going in 'Runtime' > 'Disconnect and delete runtime' to get a new IP. If the problem persists, then you will have to run locally using selenium and solve the captchas manually. Make sure to avoid running this code too often to avoid the robot checking problem._
#
# Next, you will see that a csv file with the name of the keyword was created (which is `deep_learning.csv` in my case).

# %%
ls
# Out:
# '"AI_Literacy"_AND_"scale".csv'  '"AI_Literacy"_AND_scale.csv'   sample_data/

# %% [markdown]
# Let's import this file to visualize some results (make sure to change `deep_learning.csv` to the file name that was created in your case):

# %%
import pandas as pd
df = pd.read_csv('"AI_Literacy"_AND_"scale".csv') # OBS: Update the file name

# %%
df.head(10)
# Out:
# Empty DataFrame
# Columns: [Rank, Author, Title, Citations, Year, Publisher, Venue, Source, cit/year]
# Index: []

# %% [markdown]
# Above we have the top 10 papers of deep learning ranked by citations per year. It is incredible that some papers are very far away from the original rank. For example, the fourth most cited paper per year is originally the number 41 in the original rank of Google!

# %% [markdown]
# Finally, let's download the CSV results (make sure to update the CSV name here as well):

# %%
from google.colab import files
files.download('"AI_Literacy"_AND_"scale".csv') # Update the file name here

# %% [markdown]
# OBS: If you get an error running the previous line, you can download the file manually by clicking in the left pane icon (below the `+ Code` button), then click in files, expand the `sort-google-scholar` folder, right click and download in the csv file:
#
# ![](https://i.stack.imgur.com/KKJXFm.png)
